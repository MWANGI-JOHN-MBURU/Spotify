# %% [markdown]
# <a href="https://colab.research.google.com/github/MWANGI-JOHN-MBURU/Spotify/blob/main/spotfy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/spotify_churn_dataset.csv')

# %%
df
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 0           1  Female   54      CA              Free              26
# 1           2   Other   33      DE            Family             141
# 2           3    Male   38      AU           Premium             199
# 3           4  Female   22      CA           Student              36
# 4           5   Other   29      US            Family             250
# ...       ...     ...  ...     ...               ...             ...
# 7995     7996   Other   44      DE           Student             237
# 7996     7997    Male   34      AU           Premium              61
# 7997     7998  Female   17      US              Free              81
# 7998     7999  Female   34      IN           Student             245
# 7999     8000   Other   45      AU              Free             210
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# ...

# %%
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.shape
# Out:
# (8000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.groupby('gender')['user_id'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='user_id'>

# %%
df.groupby('subscription_type')['user_id'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='subscription_type'>

# %%
df.groupby('country')['user_id'].count().sort_values(ascending=False)
# Out:
# country
# AU    1034
# US    1032
# DE    1015
# IN    1011
# PK     999
# FR     989
# UK     966
# CA     954
# Name: user_id, dtype: int64

# %%
df.groupby('device_type')['user_id'].count()
# Out:
# device_type
# Desktop    2778
# Mobile     2599
# Web        2623
# Name: user_id, dtype: int64

# %%
df['listening_time'].mean().astype(int)
# Out:
# np.int64(154)

# %%
df.describe()
# Out:
#           user_id          age  listening_time  songs_played_per_day  \
# count  8000.00000  8000.000000     8000.000000           8000.000000
# mean   4000.50000    37.662125      154.068250             50.127250
# std    2309.54541    12.740359       84.015596             28.449762
# min       1.00000    16.000000       10.000000              1.000000
# 25%    2000.75000    26.000000       81.000000             25.000000
# 50%    4000.50000    38.000000      154.000000             50.000000
# 75%    6000.25000    49.000000      227.000000             75.000000
# max    8000.00000    59.000000      299.000000             99.000000
#
#          skip_rate  ads_listened_per_week  offline_listening   is_churned
# count  8000.000000            8000.000000        8000.000000  8000.000000
# mean      0.300127               6.943875           0.747750     0.258875
# std       0.173594              13.617953           0.434331     0.438044
# ...

# %%
correlation=round(df.corr(numeric_only=True),2)
correlation
# Out:
#                        user_id   age  listening_time  songs_played_per_day  \
# user_id                   1.00  0.01           -0.01                  0.02
# age                       0.01  1.00           -0.01                 -0.01
# listening_time           -0.01 -0.01            1.00                 -0.01
# songs_played_per_day      0.02 -0.01           -0.01                  1.00
# skip_rate                 0.01 -0.02           -0.01                 -0.00
# ads_listened_per_week    -0.01 -0.01            0.00                 -0.02
# offline_listening         0.00  0.02           -0.01                  0.02
# is_churned               -0.02  0.00           -0.01                  0.01
#
#                        skip_rate  ads_listened_per_week  offline_listening  \
# user_id                     0.01                  -0.01               0.00
# age                        -0.02                  -0.01               0.02
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(correlation,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.groupby('subscription_type')['user_id'].count()
# Out:
# subscription_type
# Family     1908
# Free       2018
# Premium    2115
# Student    1959
# Name: user_id, dtype: int64

# %%
df.replace({'subscription_type':{'Free':0,'Family':1,'Premium':2,'Student':3}},inplace=True)
# Out:
# /tmp/ipython-input-147321395.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'subscription_type':{'Free':0,'Family':1,'Premium':2,'Student':3}},inplace=True)

# %%
df['subscription_type'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    1
# Name: subscription_type, dtype: int64

# %%
df.head()
# Out:
#    user_id  gender  age country  subscription_type  listening_time  \
# 0        1  Female   54      CA                  0              26
# 1        2   Other   33      DE                  1             141
# 2        3    Male   38      AU                  2             199
# 3        4  Female   22      CA                  3              36
# 4        5   Other   29      US                  1             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.groupby('gender')['user_id'].count()
# Out:
# gender
# Female    2659
# Male      2691
# Other     2650
# Name: user_id, dtype: int64

# %%
df.replace({'gender':{'Male':0,'Female':1,'Other':2}},inplace=True)
# Out:
# /tmp/ipython-input-1206786694.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'gender':{'Male':0,'Female':1,'Other':2}},inplace=True)

# %%
df.head()
# Out:
#    user_id  gender  age country  subscription_type  listening_time  \
# 0        1       1   54      CA                  0              26
# 1        2       2   33      DE                  1             141
# 2        3       0   38      AU                  2             199
# 3        4       1   22      CA                  3              36
# 4        5       2   29      US                  1             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.groupby('device_type')['user_id'].count()
# Out:
# device_type
# Desktop    2778
# Mobile     2599
# Web        2623
# Name: user_id, dtype: int64

# %%
df.replace({'device_type':{'Mobile':0,'Desktop':1,'Web':2}},inplace=True)
# Out:
# /tmp/ipython-input-1318047714.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'device_type':{'Mobile':0,'Desktop':1,'Web':2}},inplace=True)

# %%
df.head()
# Out:
#    user_id  gender  age country  subscription_type  listening_time  \
# 0        1       1   54      CA                  0              26
# 1        2       2   33      DE                  1             141
# 2        3       0   38      AU                  2             199
# 3        4       1   22      CA                  3              36
# 4        5       2   29      US                  1             250
#
#    songs_played_per_day  skip_rate  device_type  ads_listened_per_week  \
# 0                    23       0.20            1                     31
# 1                    62       0.34            2                      0
# 2                    38       0.04            0                      0
# 3                     2       0.31            0                      0
# 4                    57       0.36            0                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# ...

# %%
x=df.drop(columns=['user_id','is_churned','country'])

# %%
y=df['is_churned']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
model=DecisionTreeClassifier()
model.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=model.predict(x_test_scaled)

# %%
m2=RandomForestClassifier()
m2.fit(x_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
pred2=m2.predict(x_test_scaled)

# %%
accuracy=accuracy_score(y_test,prediction)
print(f'Accuracy:{accuracy}')
confussion=confusion_matrix(y_test,prediction)
print(f'Confusion Matrix:\n{confussion}')
classification=classification_report(y_test,prediction)
print(f'Classification Report:\n{classification}')
precision= precision_score(y_test,prediction)
print(f'Precision:{precision}')
recall=recall_score(y_test,prediction)
print(f'Recall:{recall}')
# Out:
# Accuracy:0.616875
# Confusion Matrix:
# [[854 346]
#  [267 133]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.74      1200
#            1       0.28      0.33      0.30       400
#
#     accuracy                           0.62      1600
#    macro avg       0.52      0.52      0.52      1600
# weighted avg       0.64      0.62      0.63      1600
#
# Precision:0.2776617954070981
# Recall:0.3325

# %%
sns.heatmap(confussion, annot=True, cmap='Blues', fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
accuracy2=accuracy_score(y_test,pred2)
print(f'Accuracy:{accuracy2}')
# Out:
# Accuracy:0.740625

# %%
precision2= precision_score(y_test,pred2)
print(f'Precision:{precision2}')
# Out:
# Precision:0.25806451612903225

# %%
report=classification_report(y_test,pred2)
print(f'Classification Report:\n{report}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85      1200
#            1       0.26      0.02      0.04       400
#
#     accuracy                           0.74      1600
#    macro avg       0.50      0.50      0.44      1600
# weighted avg       0.63      0.74      0.65      1600

# %%
conf2=confusion_matrix(y_test,pred2)
print(f'Confusion Matrix:\n{conf2}')
# Out:
# Confusion Matrix:
# [[1177   23]
#  [ 392    8]]

# %%
sns.heatmap(conf2, annot=True, cmap='Blues', fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
